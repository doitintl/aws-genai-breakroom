# %% [markdown]
# # Music Data Analysis with AWS Bedrock

# %% [markdown]
# ## FMA (Free Music Archive) Data Model

# %% [markdown]
# <pre>
# +-----------------+ 1       n +-----------------+ 1       n +-----------------+
# |                 |<----------|                 |<----------|                 |
# |     Genres      |           |     Tracks      |           |     Albums      |
# |                 |           |                 |           |                 |
# +-----------------+           +-----------------+           +-----------------+
# | genre_id  (PK)  |           | genre_id (FK)   |           | album_id  (PK)  |
# | genre_title     |           | track_id  (PK)  |           | album_title     |
# | ...             |           | album_id (FK)   |<----------| artist_name (FK)|
# +-----------------+           | artist_id (FK)  |           | ...             |
#                               | track_title     |           +-----------------+
#                               | ...             |
#                               +-----------------+
#                                       |
#                                       | 1       n
#                                       V
#                                +-----------------+
#                                |                 |
#                                |     Artists     |
#                                |                 |
#                                +-----------------+
#                                | artist_id  (PK) |
#                                | artist_name     |
#                                | ...             |
#                                +-----------------+
# </pre>

# %% [markdown]
# ## FMA DataModel
#
# #### Genres (genres.csv):
# This table contains information about different music genres. It has five columns: genre_id, genre_color, genre_handle, genre_parent_id, and genre_title. The primary key for this table is genre_id, which is a unique identifier for each genre.
# #### Tracks (raw_tracks.csv):
# This table contains detailed information about tracks. It includes columns like track_id, album_id, artist_id, track_genres, etc. The primary key for this table is track_id. This table has foreign keys album_id and artist_id which link to the Albums and Artists tables respectively. The track_genres column contains a list of genres associated with each track, which can be linked to the genre_id in the Genres table.
# #### Albums (albums.csv):
# This table contains information about different music albums. It has columns like album_id, album_title, artist_name, etc. The primary key for this table is album_id, and it has a foreign key artist_name linking to the Artists table
# #### Artists (artists.csv):
# This table contains information about different artists. It has columns like artist_id, artist_name, artist_website, etc. The primary key for this table is artist_id

# %% [markdown]
# ### Import Libraries Load the data from S3

# %%
# pip install boto3 pandas

# %%
from sklearn.model_selection import train_test_split
import boto3
import json
import pandas as pd
import ast

# Initialize boto3 client for S3
s3 = boto3.client('s3', region_name='us-east-1')
bucket_name='fma-data-analysis'
raw_files_prefix='raw/'

# %%
def load_csv_from_s3(bucket_name, file_name):
    print(file_name)
    obj = s3.get_object(Bucket=bucket_name, Key=file_name)
    df = pd.read_csv(obj['Body'])
    return df

# %%
# Load each CSV file into a DataFrame
tracks = load_csv_from_s3(bucket_name, raw_files_prefix+'raw_tracks.csv')
genres = load_csv_from_s3(bucket_name, raw_files_prefix+'raw_genres.csv')
# features = load_csv_from_s3(bucket_name, raw_files_prefix+'features.csv')
# echonest = load_csv_from_s3(bucket_name, raw_files_prefix+'echonest.csv')
# Out:
# raw/raw_tracks.csv
# raw/raw_genres.csv

# %%
tracks.head(2)
# Out:
#    track_id  album_id           album_title  \
# 0         2       1.0  AWOL - A Way Of Life
# 1         3       1.0  AWOL - A Way Of Life
#
#                                            album_url  artist_id artist_name  \
# 0  http://freemusicarchive.org/music/AWOL/AWOL_-_...          1        AWOL
# 1  http://freemusicarchive.org/music/AWOL/AWOL_-_...          1        AWOL
#
#                                 artist_url  \
# 0  http://freemusicarchive.org/music/AWOL/
# 1  http://freemusicarchive.org/music/AWOL/
#
#                             artist_website  \
# 0  http://www.AzillionRecords.blogspot.com
# 1  http://www.AzillionRecords.blogspot.com
#
#                                   license_image_file  \
# 0  http://i.creativecommons.org/l/by-nc-sa/3.0/us...
# 1  http://i.creativecommons.org/l/by-nc-sa/3.0/us...
#
#                             license_image_file_large  ...  track_instrumental  \
# 0  http://fma-files.s3.amazonaws.com/resources/im...  ...                   0
# 1  http://fma-files.s3.amazonaws.com/resources/im...  ...                   0
#
#   track_interest track_language_code track_listens  track_lyricist  \
# 0           4656                  en          1293             NaN
# 1           1470                  en           514             NaN
#
#    track_number track_publisher   track_title  \
# 0             3             NaN          Food
# 1             4             NaN  Electric Ave
#
#                                            track_url genre_titles
# 0  http://freemusicarchive.org/music/AWOL/AWOL_-_...    [Hip-Hop]
# 1  http://freemusicarchive.org/music/AWOL/AWOL_-_...    [Hip-Hop]
#
# [2 rows x 40 columns]

# %% [markdown]
# ## Example 1: Generating a music artist bio using the genre of their songs

# %%
def extract_genre_id(track_genres):
    if pd.isna(track_genres):
        return None
    genre_list = ast.literal_eval(track_genres)
    if genre_list:
        return int(genre_list[0]['genre_id'])
    else:
        return None

# %%
tracks['genre_id'] = tracks['track_genres'].apply(extract_genre_id)

# %%
data.head(2)
# Out:
#    track_id  album_id           album_title  \
# 0         2       1.0  AWOL - A Way Of Life
# 1         3       1.0  AWOL - A Way Of Life
#
#                                            album_url  artist_id artist_name  \
# 0  http://freemusicarchive.org/music/AWOL/AWOL_-_...          1        AWOL
# 1  http://freemusicarchive.org/music/AWOL/AWOL_-_...          1        AWOL
#
#                                 artist_url  \
# 0  http://freemusicarchive.org/music/AWOL/
# 1  http://freemusicarchive.org/music/AWOL/
#
#                             artist_website  \
# 0  http://www.AzillionRecords.blogspot.com
# 1  http://www.AzillionRecords.blogspot.com
#
#                                   license_image_file  \
# 0  http://i.creativecommons.org/l/by-nc-sa/3.0/us...
# 1  http://i.creativecommons.org/l/by-nc-sa/3.0/us...
#
#                             license_image_file_large  ...  track_lyricist  \
# 0  http://fma-files.s3.amazonaws.com/resources/im...  ...             NaN
# 1  http://fma-files.s3.amazonaws.com/resources/im...  ...             NaN
#
#   track_number track_publisher   track_title  \
# 0            3             NaN          Food
# 1            4             NaN  Electric Ave
#
#                                            track_url  genre_id genre_color  \
# 0  http://freemusicarchive.org/music/AWOL/AWOL_-_...      21.0     #CC0000
# 1  http://freemusicarchive.org/music/AWOL/AWOL_-_...      21.0     #CC0000
#
#   genre_handle genre_parent_id genre_title
# 0      Hip-Hop             NaN     Hip-Hop
# 1      Hip-Hop             NaN     Hip-Hop
#
# [2 rows x 44 columns]

# %%
data['prompt'] = f"\n\nHuman: Write a captivating bio for the electronic music artist {data['artist_name']}, who is known for their {data['genre_title']} music.\n\nAssistant:"

# %%
from io import StringIO
import sys
import textwrap

def print_ww(*args, width: int = 100, **kwargs):
    """Like print(), but wraps output to `width` characters (default 100)"""
    buffer = StringIO()
    try:
        _stdout = sys.stdout
        sys.stdout = buffer
        print(*args, **kwargs)
        output = buffer.getvalue()
    finally:
        sys.stdout = _stdout
    for line in output.splitlines():
        print("\n".join(textwrap.wrap(line, width=width)))

# %% [markdown]
# ### Initializing Bedrock client

# %%
import boto3,os
import sys

boto3_bedrock = bedrock.get_bedrock_client(
    assumed_role=os.environ.get("BEDROCK_ASSUME_ROLE", None),
    region=os.environ.get("AWS_DEFAULT_REGION", None)
)
# Out:
# Create new client
#   Using region: us-east-1
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-east-1.amazonaws.com)

# %%
# %pip install --no-build-isolation --force-reinstall \
#     "boto3>=1.28.57" \
#     "awscli>=1.29.57" \
#     "botocore>=1.31.57"

# %%
genre_dict = genres.set_index('genre_id')['genre_title'].to_dict()

def extract_genre_titles(track_genres):
    if pd.isna(track_genres):
        return None
    genre_list = ast.literal_eval(track_genres)
    genre_titles = []
    for genre in genre_list:
        genre_id = int(genre['genre_id'])
        if genre_id in genre_dict:
            genre_titles.append(genre_dict[genre_id])
    return genre_titles

tracks['genre_titles'] = tracks['track_genres'].apply(extract_genre_titles)

# %%
tracks_with_multiple_genres = tracks[tracks['genre_titles'].apply(lambda x: len(x) > 1 if x is not None else False)]

tracks_with_multiple_genres.head(5)
# Out:
#    track_id  album_id album_title  \
# 4        20       4.0       Niris
# 5        26       4.0       Niris
# 6        30       4.0       Niris
# 7        46       4.0       Niris
# 8        48       4.0       Niris
#
#                                            album_url  artist_id artist_name  \
# 4  http://freemusicarchive.org/music/Chris_and_Ni...          4  Nicky Cook
# 5  http://freemusicarchive.org/music/Chris_and_Ni...          4  Nicky Cook
# 6  http://freemusicarchive.org/music/Chris_and_Ni...          4  Nicky Cook
# 7  http://freemusicarchive.org/music/Chris_and_Ni...          4  Nicky Cook
# 8  http://freemusicarchive.org/music/Chris_and_Ni...          4  Nicky Cook
#
#                                           artist_url artist_website  \
# 4  http://freemusicarchive.org/music/Chris_and_Ni...            NaN
# 5  http://freemusicarchive.org/music/Chris_and_Ni...            NaN
# 6  http://freemusicarchive.org/music/Chris_and_Ni...            NaN
# 7  http://freemusicarchive.org/music/Chris_and_Ni...            NaN
# 8  http://freemusicarchive.org/music/Chris_and_Ni...            NaN
#
#                                   license_image_file  \
# 4  http://i.creativecommons.org/l/by-nc-nd/3.0/88...
# 5  http://i.creativecommons.org/l/by-nc-nd/3.0/88...
# 6  http://i.creativecommons.org/l/by-nc-nd/3.0/88...
# 7  http://i.creativecommons.org/l/by-nc-nd/3.0/88...
# 8  http://i.creativecommons.org/l/by-nc-nd/3.0/88...
#
#                             license_image_file_large  ...  track_interest  \
# 4  http://fma-files.s3.amazonaws.com/resources/im...  ...             978
# 5  http://fma-files.s3.amazonaws.com/resources/im...  ...            1060
# 6  http://fma-files.s3.amazonaws.com/resources/im...  ...             718
# 7  http://fma-files.s3.amazonaws.com/resources/im...  ...             252
# 8  http://fma-files.s3.amazonaws.com/resources/im...  ...             247
#
#   track_language_code track_listens track_lyricist  track_number  \
# 4                  en           361            NaN             3
# 5                  en           193            NaN             4
# 6                  en           612            NaN             5
# 7                  en           171            NaN             8
# 8                  en           173            NaN             9
#
#    track_publisher          track_title  \
# 4              NaN      Spiritual Level
# 5              NaN  Where is your Love?
# 6              NaN            Too Happy
# 7              NaN             Yosemite
# 8              NaN       Light of Light
#
#                                            track_url  \
# 4  http://freemusicarchive.org/music/Chris_and_Ni...
# 5  http://freemusicarchive.org/music/Chris_and_Ni...
# 6  http://freemusicarchive.org/music/Chris_and_Ni...
# 7  http://freemusicarchive.org/music/Chris_and_Ni...
# 8  http://freemusicarchive.org/music/Chris_and_Ni...
#
#                                     genre_hierarchy  \
# 4  [Experimental Pop, Pop, Singer-Songwriter, Folk]
# 5  [Experimental Pop, Pop, Singer-Songwriter, Folk]
# 6  [Experimental Pop, Pop, Singer-Songwriter, Folk]
# 7  [Experimental Pop, Pop, Singer-Songwriter, Folk]
# 8  [Experimental Pop, Pop, Singer-Songwriter, Folk]
#
#                             genre_titles
# 4  [Experimental Pop, Singer-Songwriter]
# 5  [Experimental Pop, Singer-Songwriter]
# 6  [Experimental Pop, Singer-Songwriter]
# 7  [Experimental Pop, Singer-Songwriter]
# 8  [Experimental Pop, Singer-Songwriter]
#
# [5 rows x 41 columns]

# %%
# Group tracks by artist and combine genre titles
grouped_tracks = tracks_with_multiple_genres.groupby('artist_name')['genre_titles'].sum().reset_index()
grouped_tracks_subset = grouped_tracks.head(5)

# %% [markdown]
# ### Invoking the model Anthropic Claude V2

# %% [markdown]
# * <b>prompt:</b> This is the initial string of text that the model uses as a starting point to generate further text. It sets the context for the generated text 1.
# max_tokens_to_sample: This parameter specifies the maximum number of tokens to generate in the response. A token can be as short as one character or as long as one word. This parameter is used to control the length of the generated text.
# * <b>temperature:</b>  This parameter controls the randomness of the model's responses. A lower value (closer to 0) makes the model's outputs more deterministic and focused, while a higher value increases the randomness and diversity of the output.
# * <b>top_k:</b> This parameter is used during the sampling process to restrict the pool of words that the model considers for the next word in the sequence. The model will only sample from the * top_k most probable words when generating the next word. This can help control the randomness of the output.
# * <b>top_p:</b> Also known as nucleus sampling, this parameter is used to further control the randomness in the model's output. It cuts off the least probable options, ensuring that the cumulative probability of the chosen options is at least top_p. This can help in reducing the randomness and improving the quality of the output.
# * <b>stop_sequences:</b> This parameter allows you to specify sequences of tokens that, when encountered, signal the model to stop generating further tokens. This can be useful to control where the generated text ends.

# %%
num_tokens = textgen_llm.get_num_tokens(prompt)

# %%
modelId = 'anthropic.claude-v2' 
for index, row in grouped_tracks_subset.iterrows():
    artist_name = row['artist_name']
    genre_titles = ', '.join(set(row['genre_titles']))  # Use set to remove duplicates
    prompt_data = f"\n\nHuman: Write a captivating bio for the electronic music artist {artist_name}, who is known for their {genre_titles} music.\n\nAssistant:"
    print(prompt_data)

     # Claude - Body Syntex
    body = json.dumps({
                    "prompt": prompt_data,
                    "max_tokens_to_sample":4096,
                    "temperature":1,
                    "top_k":250,
                    "top_p":0.5,
                    "stop_sequences": ["\n\nHuman:"]
                  }) 
    response = boto3_bedrock.invoke_model(body=body, modelId=modelId, accept='application/json', contentType='application/json')
    response_body = json.loads(response.get('body').read())
    print_ww(response_body.get('completion'))
# Out:
# Human: Write a captivating bio for the electronic music artist "Blue" Gene Tyranny, who is known for their Avant-Garde, Experimental, Composed Music music.
#
# Assistant:
#  Here is a draft captivating bio for the electronic music artist "Blue" Gene Tyranny:
#
# Pushing the boundaries of avant-garde electronic music since the 1970s, "Blue" Gene Tyranny has
# carved out a unique space in the experimental and composed music worlds. Tyranny's innovative
# compositions blend electronic textures with acoustic instruments, fusing classical sensibilities
# with cutting-edge techniques.
#
# Whether collaborating with giants like Robert Ashley or creating solo works, Tyranny's music
# inhabits a realm between pure sound and structure. Hypnotic yet cerebral, Tyranny's compositions
# reveal hidden patterns and meanings upon repeated listens. Yet they always retain an air of mystery
# and discovery.
#
# A true pioneer in the electronic arts, Tyranny helped develop the very first sampling keyboard, the
# SampleMaster. This enabled new ways of manipulating and sequencing sounds that were previously
# unimaginable. Tyranny's mastery of this emerging technology put him at the forefront of electronic
# music's evolution.
#
# While difficult to categorize, Tyranny's oeuvre shows a singular artistic vision applied across
# diverse mediums. From avant-jazz to multimedia works, Tyranny brings a searching experimental spirit
# to every endeavor. His uncompromising commitment to following his muse, regardless of critical or
# commercial reception, has made Tyranny a highly influential underground figure.
#
# After decades of sonic explorations, "Blue" Gene Tyranny continues to push boundaries and evade easy
# definitions. His body of work forms a bridge between the 20th century avant-garde and today's
# electronic frontiers. Tyranny's constant innovation and iconoclastic approach cement his reputation
# as one of experimental music's most treasured cult heroes.
#
#
# Human: Write a captivating bio for the electronic music artist #CCmixtape, who is known for their Classical, Electronic, Instrumental, Ambient music.
#
# Assistant:
#  Here is a draft bio for the electronic music artist #CCmixtape:
#
# Transcending genres and captivating listeners, #CCmixtape creates music that stirs the soul.
# Blending classical compositions with modern electronic and ambient soundscapes, #CCmixtape produces
# rich instrumental tracks that feel both timeless and cutting-edge.
#
# Though #CCmixtape started out anonymously posting tracks online, their music quickly garnered
# attention for its innovative fusion of old and new. As their soothing synthetic strings and piano
# weave around glitchy beats and ethereal pads, #CCmixtape transports audiences to otherworldly
# realms. Yet their classically-inspired melodies remain accessible and familiar.
#
# Each track by #CCmixtape envelops the listener, evoking nostalgia and future vision simultaneously.
# Their ambient arrangements evolve unhurriedly, inviting reflection and imagination. Both epic and
# intimate, #CCmixtape's catalog ranges from tranquil meditations to soaring anthems. But every piece
# retains their signature style: heartfelt melodies rising from a bed of technology and
# experimentation.
#
# With one foot in the concert hall and the other in the dance club, #CCmixtape is a pioneering voice
# in modern electronic music. Their commitment to melding classical composition with electronic
# innovation makes #CCmixtape a producer to watch. Each release charts new sonic territory, delicately
# balancing human emotion with digital wonder.
#
#
# Human: Write a captivating bio for the electronic music artist $50 Trumpet, who is known for their Field Recordings, Avant-Garde, Electroacoustic, Musique Concrete, Experimental music.
#
# Assistant:
#  Here is a draft bio for the electronic music artist $50 Trumpet:
#
# $50 Trumpet is an avant-garde electronic music producer known for creating immersive soundscapes
# from found sounds and field recordings. Their experimental approach combines electroacoustic
# techniques, musique concrète, and the avant-garde spirit to produce music that is subtly subversive
# yet profoundly moving.
#
# Based in [city], $50 Trumpet gleans inspiration from the mundane noises of everyday life. Using
# cheap recording equipment purchased for the price of a trumpet, they capture the strange rhythms of
# public spaces, the resonant hums of machinery, and the whispered echoes within abandoned buildings.
# These raw field recordings are then transformed through intricate editing and bold juxtaposition
# into the backbone of $50 Trumpet's singular musical vision.
#
# While often atmospheric and gently disorienting, $50 Trumpet's work maintains an emotional core.
# Their use of repetition and slow transformation reveals the humanity within commonplace sounds,
# drawing listeners into liminal spaces between noise and melody. $50 Trumpet calls listeners to pause
# and truly hear the poetry of the world around us.
#
# Through a DIY approach and daring sonic combinations, $50 Trumpet's music gives voice to the
# unheard. Their immersive live audiovisual performances showcase sound as an art form, inviting
# audiences into a meditative yet provocative experience. As an avant-garde force, $50 Trumpet expands
# the boundaries of electronic music to reveal the extraordinary within the ordinary.
#
#
# Human: Write a captivating bio for the electronic music artist ( Early ) Salomè Lego Playset, who is known for their Punk, Unclassifiable, Sound Collage music.
#
# Assistant:
#  Here is a draft bio for the electronic music artist Early Salomè Lego Playset:
#
# Early Salomè Lego Playset burst onto the experimental electronic scene with their debut album
# "Building Block Beats" in 2019. Known for using Lego bricks as instruments and sound sources,
# Salomè's music combines punk attitude, pop sensibilities, and avant-garde sound collage techniques
# into an utterly unclassifiable yet infectious sound.
#
# Hailing from a small town in Denmark, Salomè became obsessed with Lego from an early age. They began
# experimenting with manipulating and circuit-bending Lego parts to generate unique tones and
# textures. After posting some early SoundCloud demos, their DIY Lego-based compositions attracted an
# underground following.
#
# When Salomè performs live, they assemble different Lego contraptions on stage to create each song.
# Their inventive sets and energetic on-stage persona have earned Salomè a reputation as one of the
# most entertaining live acts in electronic music today. As their popularity has grown, Salomè has
# upgraded from basic Lego bricks to specialized kits and motors to expand their sonic palette.
#
# While Salomè's accessible, hook-laden music has expanded their fanbase, their experimentation with
# abstract Lego soundscapes maintains their cred with electronic aficionados. When asked to describe
# their music, Salomè simply states: "I build beats and melodies piece by piece." Early Salomè Lego
# Playset continues to cement their place at the forefront of playful postmodern electronic music.
#
#
# Human: Write a captivating bio for the electronic music artist ((( vlubä ))), who is known for their Avant-Garde, Experimental, Noise music.
#
# Assistant:
#  Here is a draft bio for the electronic music artist ((( vlubä ))):
#
# Pushing the boundaries of sound, ((( vlubä ))) is an avant-garde electronic music producer known for
# their experimental and noise compositions. Hailing from [city], this enigmatic artist emerged onto
# the scene in [year], quickly garnering attention for their unorthodox production techniques and
# abrasive sonic textures.
#
# Each ((( vlubä ))) track is a journey into the unknown, blending dissonant frequencies, glitchy
# rhythms, and obscure found sounds into something entirely uncharted. Their debut album [album name]
# was described by critics as "jarringly futuristic" and "challenging yet captivating". Never sticking
# to genre constraints, ((( vlubä ))) draws inspiration from noise, industrial, drone, and musique
# concrète, deforming the familiar into something wholly alien.
#
# Bringing their arresting live audiovisual shows to venues around the world, ((( vlubä ))) aims to
# fully immerse audiences in their upside-down universe of sound. Through their bold experimentation
# and rejection of musical conventions, ((( vlubä ))) provides a portal into a new sonic realm that
# transcends mainstream electronic music. Love it or hate it, their avant-garde noise compositions are
# impossible to ignore, proving ((( vlubä ))) to be one of the most exciting and innovative electronic
# producers right now.

# %% [markdown]
# ## Example 2: Summarizing the most popular music genres

# %%
tracks_sample = load_csv_from_s3(bucket_name, raw_files_prefix+'tracks_sample.csv')
# Out:
# raw/tracks_sample.csv

# %%
# Convert DataFrame to string
# Select relevant columns
tracks_df = tracks_sample[['track_id', 'album_id', 'artist_name', 'track_genres']]
tracks_sample_str = tracks_df.to_string(index=False)

# %%
prompt = f"Human:{tracks_sample_str}\n\nGenerate a summary of the most popular music genres in this data.\n\nAssistant:"

# %%
body = json.dumps({
                "prompt": prompt,
                "max_tokens_to_sample":4096,
                "temperature":1,
                "top_k":250,
                "top_p":0.5,
                "stop_sequences": ["\n\nHuman:"]
              }) 


response = boto3_bedrock.invoke_model(body=body, modelId=modelId, accept='application/json', contentType='application/json')
response_body = json.loads(response.get('body').read())
print_ww(response_body.get('completion'))
# Out:
#  Here is a summary of the most popular music genres in the data:
#
# - The most common genre is 'Rock', with 192 track entries.
#
# - The second most common is 'Electronic', with 144 entries.
#
# - 'Folk' is third with 139 entries.
#
# - 'Hip-Hop' has 97 entries.
#
# - 'Punk' has 91 entries.
#
# - 'Pop' has 87 entries.
#
# - 'Jazz' has 84 entries.
#
# - 'Avant-Garde' has 67 entries.
#
# - 'Experimental' has 64 entries.
#
# - 'Lo-Fi' has 62 entries.
#
# So in summary, the most popular genres in descending order are:
#
# 1. Rock
# 2. Electronic
# 3. Folk
# 4. Hip-Hop
# 5. Punk
# 6. Pop
# 7. Jazz
# 8. Avant-Garde
# 9. Experimental
# 10. Lo-Fi
#
# This gives a good overview of the most common genres present in the music data. Rock is clearly the
# most prevalent, followed by electronic and folk styles.

# %% [markdown]
# ### Example 3: Creating playlists of songs in different genre

# %%
# Convert DataFrame to string
# Select relevant columns
tracks_df = tracks_sample[['track_title', 'album_title', 'artist_name', 'track_genres']]
tracks_sample_str = tracks_df.to_string(index=False)

prompt = f"Human:{tracks_sample_str}\n\nCreate playlists of 30 songs in Rock and Electronic Genre.\n\nAssistant:"

# %%
body = json.dumps({
                "prompt": prompt,
                "max_tokens_to_sample":4096,
                "temperature":1,
                "top_k":250,
                "top_p":0.5,
                "stop_sequences": ["\n\nHuman:"]
              }) 


response = boto3_bedrock.invoke_model(body=body, modelId=modelId, accept='application/json', contentType='application/json')
response_body = json.loads(response.get('body').read())
print_ww(response_body.get('completion'))
# Out:
#  Here are two 30 song playlists, one for the Rock genre and one for the Electronic genre:
#
# Rock Playlist:
#
# track_title                                                   album_title
# artist_name
# Referents                                             Open Relationship
# Bird Names
# A New Map for Kissing                                              On Opaque Things
# Bird Names
# Ghosts                                      Wooden Lake Sexual Diner
# Bird Names
# The Indefinite Time Yet to Come                                              On Opaque Things
# Bird Names
# Smoovebiz                                      Wooden Lake Sexual Diner
# Bird Names
# Nobody Loves Me                                      Wooden Lake Sexual Diner
# Bird Names
# It's Becoming a Stranger                                              On Opaque Things
# Bird Names
# New Life                                             Open Relationship
# Bird Names
# Masters Of Enjoyment                                             Open Relationship
# Bird Names
# We Want to be Old                                              On Opaque Things
# Bird Names
# Toggle                                                     Black Elk
# Black Elk
# My Lil'                                                     Black Elk
# Black Elk
# Eyebone                                                     Black Elk
# Black Elk
# Juggernaut Soliloquy                        On the Back of a Dying Beast: Volume 1
# Borful Tang
# The Tides Of Land                        On the Back of a Dying Beast: Volume 1
# Borful Tang
# Borful Tang Loves Nomeansno                                                          Root
# Borful Tang
# Majestic Shuffle                                                          Root
# Borful Tang
# The Tides Of Land                  split with Sunshine Militant Children's Hour
# Borful Tang
# Lost on the Eastern Side of the Island                                                          Root
# Borful Tang
# Orp                                                          Root
# Borful Tang
# John And Mary - The Meeting                                                          Root
# Borful Tang
# Smyrna Snow Walk                                                          Root
# Borful Tang
# ELI                        On the Back of a Dying Beast: Volume 1
# Borful Tang
# Soundclash At Wonder Inn (ft. Qulfus)                                                          Root
# Borful Tang
# The Tides Of Land                  split with Sunshine Militant Children's Hour
# Borful Tang
# John And Mary - The Restaurant                                                          Root
# Borful Tang
# Untitled Boogie (edit), Transfiguration Boogie, Boogie Hole
# Boogie Witch
# Boogie Hole                                                  Boogie Witch
# Transfiguration Boogie                                                  Boogie Witch
# Indian Giver                                       Funeral Home Session 7"                        El
# Jesus De Magico
# LGNO                                       Funeral Home Session 7"                        El Jesus
# De Magico
# Xmas at Wounded Knee                                       Funeral Home Session 7"
# El Jesus De Magico
#
# Electronic Playlist:
#
# track_title                                                   album_title
# artist_name
# Side One - Introduction                                 Spree: An Escape From Reality
# Ethan Persoff
# SNAP! (side one of two)                                                         SNAP!
# Ethan Persoff
# Side One - The Talent Contest                                 Spree: An Escape From Reality
# Ethan Persoff
# SNAP! (side two of two)                                                         SNAP!
# Ethan Persoff
# Side One - Dear Mr. Depieu                                 Spree: An Escape From Reality
# Ethan Persoff
# Side One - Reprise / The Bullshit Business Proposal / (end)                                 Spree:
# An Escape From Reality                             Ethan Persoff
# Side Two - Reset (and the Great Joke)                                 Spree: An Escape From Reality
# Ethan Persoff
# Side Two - Praise the Lord and Give Thanks                                 Spree: An Escape From
# Reality                             Ethan Persoff
# Side Two - Bean Bag                                 Spree: An Escape From Reality
# Ethan Persoff
# Side Two - Jake's Theme / Intermission                                 Spree: An Escape From Reality
# Ethan Persoff
# Side Three - Part One / Start                                 Spree: An Escape From Reality
# Ethan Persoff
# Side Three - Part Two                                 Spree: An Escape From Reality
# Ethan Persoff
# Side Three - Part Three                                 Spree: An Escape From Reality
# Ethan Persoff
# Side Three - Part Four                                 Spree: An Escape From Reality
# Ethan Persoff
# Side Three - Part Five / Stop                                 Spree: An Escape From Reality
# Ethan Persoff
# Side Four - Easy Slow and Easy (finale)                                 Spree: An Escape From
# Reality                             Ethan Persoff
# Side Four - Record Label Track / Conclusion                                 Spree: An Escape From
# Reality                             Ethan Persoff
# I Stayed Home ...                                  "I Stayed Home ..." (single)
# Ethan Persoff
# Disneyland (edit) Forty Minutes Forty Memories: Horrible Music by Ethan Persoff
# Ethan Persoff
